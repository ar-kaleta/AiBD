# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import plotnine as p9
import statsmodels.api as sm

import statsmodels.formula.api as smf

df = pd.read_csv('beauty.csv')
df.head()
# Out:
#    tenured  profnumber  minority  age  beautyf2upper  beautyflowerdiv  \
# 0        0           1         1   36              6                5
# 1        1           2         0   59              2                4
# 2        1           3         0   51              5                5
# 3        1           4         0   40              4                2
# 4        0           5         0   31              9                7
#
#    beautyfupperdiv  beautym2upper  beautymlowerdiv  beautymupperdiv  ...  \
# 0                7              6                2                4  ...
# 1                4              3                2                3  ...
# 2                2              3                2                3  ...
# 3                5              2                3                3  ...
# 4                9              6                7                6  ...
#
#    nonenglish  onecredit  percentevaluating  profevaluation  students  \
# ...

# %%
#predyktory : btystdave
#dane wejściowe : pierwsze 100 rekordów

results = smf.ols('courseevaluation ~ btystdave', data=df.head(100)).fit()
wyn = results.params
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       courseevaluation   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     1.356
# Date:                Sun, 08 Dec 2019   Prob (F-statistic):              0.247
# Time:                        21:32:04   Log-Likelihood:                -81.021
# No. Observations:                 100   AIC:                             166.0
# Df Residuals:                      98   BIC:                             171.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.8963      0.055     70.883      0.000       3.787       4.005
# ...

# %%
fig=(p9.ggplot(p9.aes(x='btystdave',y='courseevaluation'),data=df.head(100))
      +p9.geom_jitter(width=0.1)
      +p9.geom_abline(p9.aes(intercept=wyn['Intercept'],slope=wyn['btystdave'])))

# %%
#model
fig
# Out:
# <ggplot: (-9223363303317199307)>

# %%
df_tail = df.tail(100).copy()
df_tail['predict1']=results.predict()
df_tail['residuals1']=abs(df_tail['courseevaluation']-df_tail['predict1'])

# %%
fig_res=(p9.ggplot(p9.aes(x='btystdave',y='residuals1'),data=df_tail)
      +p9.geom_point())

# %%
#wykres residua
fig_res
# Out:
# <ggplot: (8733537576582)>

# %%
sum(df_tail['residuals1'])/100
# Out:
# 0.5340403362240187

# %%
#model z interakcjami
#predyktory : btystdave,female
#dane wejściowe : pierwsze 100 rekordów
results = smf.ols('courseevaluation ~ btystdave + female + btystdave*female', data=df.head(100)).fit()
wyn = results.params
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       courseevaluation   R-squared:                       0.080
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     2.775
# Date:                Sun, 08 Dec 2019   Prob (F-statistic):             0.0455
# Time:                        21:32:05   Log-Likelihood:                -77.550
# No. Observations:                 100   AIC:                             163.1
# Df Residuals:                      96   BIC:                             173.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
fig=(p9.ggplot(p9.aes(x='female',y='courseevaluation'),data=df.head(100))
      +p9.geom_jitter(width=0.1)
      +p9.geom_abline(p9.aes(intercept=wyn['Intercept'],slope=wyn['female'])))

# %%
fig
# Out:
# <ggplot: (8733539500559)>

# %%
df_tail['predict2']=results.predict()
df_tail['residuals2']=abs(df_tail['courseevaluation']-df_tail['predict2'])
fig_res=(p9.ggplot(p9.aes(x='btystdave',y='residuals2'),data=df_tail)
      +p9.geom_point())
fig_res
# Out:
# <ggplot: (8733537916308)>

# %%
sum(df_tail['residuals2'])/100
# Out:
# 0.529256566663117

# %%
#predyktory : btystdaveneg,profevaluation
#dane wejściowe : pierwsze 100 rekordów

results = smf.ols('courseevaluation ~ btystdaveneg + profevaluation', data=df.head(100)).fit()
wyn = results.params
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       courseevaluation   R-squared:                       0.886
# Model:                            OLS   Adj. R-squared:                  0.884
# Method:                 Least Squares   F-statistic:                     378.2
# Date:                Sun, 08 Dec 2019   Prob (F-statistic):           1.58e-46
# Time:                        21:32:07   Log-Likelihood:                 27.016
# No. Observations:                 100   AIC:                            -48.03
# Df Residuals:                      97   BIC:                            -40.22
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
fig=(p9.ggplot(p9.aes(x='profevaluation',y='courseevaluation'),data=df.head(100))
      +p9.geom_jitter(width=0.1)
      +p9.geom_abline(p9.aes(intercept=wyn['Intercept'],slope=wyn['profevaluation'])))
fig
# Out:
# <ggplot: (8733537914383)>

# %%
df_tail['predict3']=results.predict()
df_tail['residuals3']=abs(df_tail['courseevaluation']-df_tail['predict3'])
fig_res=(p9.ggplot(p9.aes(x='courseevaluation',y='residuals3'),data=df_tail)
      +p9.geom_point())
fig_res
# Out:
# <ggplot: (8733537909575)>

# %%
sum(df_tail['residuals3'])/100
# Out:
# 0.6225417589571589

# %%
#model z interakcjami
#predyktory : btystdaveneg,profevaluation
#dane wejściowe : pierwsze 100 rekordów

results = smf.ols('courseevaluation ~ btystdaveneg + profevaluation + profevaluation*btystdaveneg', data=df.head(100)).fit()
wyn = results.params
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       courseevaluation   R-squared:                       0.892
# Model:                            OLS   Adj. R-squared:                  0.889
# Method:                 Least Squares   F-statistic:                     264.4
# Date:                Sun, 08 Dec 2019   Prob (F-statistic):           2.95e-46
# Time:                        21:32:08   Log-Likelihood:                 29.588
# No. Observations:                 100   AIC:                            -51.18
# Df Residuals:                      96   BIC:                            -40.76
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# ...

# %%
fig=(p9.ggplot(p9.aes(x='profevaluation',y='courseevaluation'),data=df.head(100))
      +p9.geom_jitter(width=0.1)
      +p9.geom_abline(p9.aes(intercept=wyn['Intercept'],slope=wyn['profevaluation'])))
fig
# Out:
# <ggplot: (8733537355910)>

# %%
df_tail['predict4']=results.predict()
df_tail['residuals4']=abs(df_tail['courseevaluation']-df_tail['predict4'])
fig_res=(p9.ggplot(p9.aes(x='courseevaluation',y='residuals4'),data=df_tail)
      +p9.geom_point())
fig_res
# Out:
# <ggplot: (8733537496952)>

# %%
sum(df_tail['residuals4'])/100
# Out:
# 0.6255147353383226
